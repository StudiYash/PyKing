# %% [markdown]
# # **🧪 Notebook 16: Assessment Test 1 – Core Python**
#
# ## 🎯 **Purpose**:
# This assessment checks your understanding of the core Python concepts covered in the first 15 notebooks of the PyKing series.
#
# ## 📘 **Topics Covered**:
#     01. Print Statement and Python Comments
#     02. Arithmetic Operators
#     03. Variable Assignment
#     04. Introduction to Strings
#     05. Indexing and Slicing
#     06. String Properties and Methods
#     07. Print Formatting with Strings
#     08. Lists in Python
#     09. Dictionaries in Python
#     10. Tuples in Python
#     11. Sets in Python
#     12. Booleans in Python
#     13. Input Output with Basic Files in Python
#     14. Comparison Operators in Python
#     15. Chaining Comparison Operators
#
# ## 📌 **Instructions**:
# - Don’t rush; read each question carefully.
# - Solve all the questions in order.
# - Use comments to explain your logic when necessary.
# - Don’t worry if you make mistakes — it’s part of learning!
#
# 🕒 Estimated Time: 60-70 minutes
# 🔓 Open Notes Allowed (your PyKing notebooks!)

# %% [markdown]
# ## **01. Print Statement and Python Comments**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# What will be the output of the following code?
# ```python
# # Welcome message
# print("Welcome to Python") # greeting
# # print("This line is hidden")
# """
# This block is
# a multi-line comment
# """
# print('End of Program') # The end
# ```
# Write the exact output as it would appear

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# The following code is giving an error. Identify and fix it.
# ```python
# print("Hello World"
# # This is a comment
# print("Python is awesome")
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Explain the difference between the following three types of comments with appropriate examples:
# - Single-line comment
# - Multi-line comment using triple double quotes
# - Multi-line comment using triple single quotes

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Given the code snippet below, how many lines of code will actually be executed (i.e., not skipped as comments)?
# ```python
# # This prints a greeting
# print("Hello!")
#
# """
# print("This is commented out")
# print("So is this")
# """
#
# print("Final line executed")
# # print("This won't run")
# ```

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Write a short Python script that does the following:
# - Prints: Welcome to Python Programming
# - Includes:
#     - A single-line comment
#     - A multi-line comment block
# - Ensures the comments do not interfere with the output.

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# Expected Output :-
#
# ```python
# Welcome to Python
# End of Program
# ```

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ❌ Error:
# - The first print() statement is missing a closing parenthesis.
# - All statements need to be properly closed.
#
# ✅ Corrected Code:
#
# ```python
# print("Hello World")
# # This is a comment
# print("Python is awesome")
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ➤ Single-line comment:
# Begins with a # and extends to the end of the line.
#
# ```python
# # This is a single-line comment
# ```
#
# ➤ Multi-line comment using triple double quotes:
#
# Uses """ ... """ and spans multiple lines.
#
# ```python
# """
# This is a multi-line comment
# using triple double quotes.
# """
# ```
#
# ➤ Multi-line comment using triple single quotes:
# Uses ''' ... ''' in a similar way.
#
# ```python
# '''
# This is a multi-line comment
# using triple single quotes.
# '''
# ```
#
# Note: Technically, both triple-quote styles are multi-line strings in Python and not actual comment syntax. However, they are often used as block comments when not assigned to a variable.

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Executed lines:
#
# ```python
# print("Hello!")
# print("Final line executed")
# ```
#
# Total executed lines = 2

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# ✅ Output:
#
# ```python
# Welcome to Python Programming
# ```

# %% [markdown]
# ## **02. Arithmetic Operators**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Predict the Output
#
# What will be the output of the following expressions?
#
# - 10 + 3 * 2
# - (10 + 3) * 2
# - 100 // 9
# - 2 ** 3 ** 2

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Construct a Valid Expression
#
# Write a Python expression using at least four different arithmetic operators that evaluates to 25. Use brackets if necessary to control precedence.

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Fill in the Blanks
#
# Complete the following code by filling in the correct arithmetic operators to make each line evaluate to True:
#
# ```python
# print(18 ___ 3 == 6)
# print(7 ___ 2 == 1)
# print(5 ___ 3 + 2 == 17)
# print(2 ** 3 ___ 10 == 6)
# ```

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Debug the Code
#
# The following code is intended to print the result of dividing 25 by 4 and also print the remainder. However, it gives incorrect results. Fix the issues.
#
# ```python
# quotient = 25 / 4
# rem = 25 // 4
# print("Quotient:", quotient)
# print("Remainder:", rem)
# ```

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Real-World Scenario
#
# A person spends ₹800 on rent, ₹1200 on groceries, and ₹500 on transportation. Their monthly income is ₹5000. Write a Python expression to calculate:
# - Their remaining balance
# - The percentage of income spent on groceries
#
# Print both answers using proper formatting.

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# Predict the Output - Answer
#
# a) 10 + 3 * 2
# → 10 + 6 = 16 ✅
#
# b) (10 + 3) * 2
# → 13 * 2 = 26 ✅
#
# c) 100 // 9
# → 11 (Integer division) ✅
#
# d) 2 ** 3 ** 2
# → 2 ** 9 = 512 (Right-to-left exponentiation) ✅

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Construct a Valid Expression
#
# One possible correct answer:
#
# ```python
# ((10 + 5) * 2 - 5) / 1  # = 25.0
# ```
#
# Or:
#
# ```python
# (30 - 5) + 2 * 0  # = 25
# ```
#
# Any expression that gives 25 using at least 4 different operators (+, -, *, /, %, **, //) is valid.

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Answers :-
#
# ```python
# print(18 / 3 == 6)      # ✅ 18 divided by 3 is 6
# print(7 % 2 == 1)       # ✅ 7 modulo 2 is 1
# print(5 ** 2 + 2 == 27) # ✅ 5^2 = 25; 25 + 2 = 27
# print(2 ** 3 - 10 == -2) # ✅ 2^3 = 8; 8 - 10 = -2
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ❌ Incorrect:
#
# ```python
# quotient = 25 / 4
# rem = 25 // 4
# ```
#
# ✅ Correct:
#
# ```python
# quotient = 25 // 4
# rem = 25 % 4
# print("Quotient:", quotient)  # 6
# print("Remainder:", rem)      # 1
# ```

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Real-World Scenario
#
# ```python
# income = 5000
# rent = 800
# groceries = 1200
# transport = 500
#
# balance = income - (rent + groceries + transport)
# grocery_percent = (groceries / income) * 100
#
# print("Remaining Balance:", balance)          # 2500
# print("Groceries % of Income:", grocery_percent)  # 24.0
# ```
#
# ✅ Output:
#
# ```python
# Remaining Balance: 2500
# Groceries % of Income: 24.0
# ```

# %% [markdown]
# ## **03. Variable Assignment**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# x = 5
# y = x + 3
# x = 10
# print("x:", x)
# print("y:", y)
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Code Completion
#
# Fill in the blanks so that all three variables a, b, and c end up with the value 15.
#
# ```python
# a = b = c = ___
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Identify and Explain the Error
#
# ```python
# a, b = 10, 20, 30
# ```
#
# Explain why the above code results in an error and how to fix it.

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Real-World Mapping
#
# You are building a weather app. Assign the following values to appropriate variables and print a sentence like:
#
# ```python
# In Pune, the temperature is 34.5°C and the weather is Sunny.
# ```
#
# Values to use:
# - City: "Pune"
# - Temperature: 34.5
# - Weather: "Sunny"
#
# Use a single print statement and variables for each item.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Dynamic Typing Challenge
#
# Examine the following code and write down the final data type of each variable:
#
# ```python
# x = 10
# x = "Ten"
# y = 5.5
# y = True
# ```
#
# What are the final data types of:
# - x = ?
# - y = ?

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
#
# ```python
# x: 10
# y: 8
# ```
#
# y was evaluated using the old value of x, so it remains 8 even after x changes.

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Code Completion
#
# ```python
# a = b = c = 15
# ```
#
# This is chained assignment, where all variables point to the same value.

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Identify and Explain the Error
# ```python
# a, b = 10, 20, 30
# ```
#
# ❌ Error:
# ```python
# ValueError: too many values to unpack (expected 2)
# ```
#
# ✅ Fix:
# ```python
# a, b, c = 10, 20, 30
# ```
#
# When unpacking a tuple/list, the number of variables must match the number of values.

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# Real-World Mapping
#
# ✅ Sample Code:
# ```python
# city = "Pune"
# temperature = 34.5
# weather = "Sunny"
#
# print(f"In {city}, the temperature is {temperature}°C and the weather is {weather}.")
# ```
#
# ✅ Output:
# ```python
# In Pune, the temperature is 34.5°C and the weather is Sunny.
# ```

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Dynamic Typing Challenge
#
# ```python
# x = 10         # int
# x = "Ten"      # now a string
# y = 5.5        # float
# y = True       # now a bool
# ```
#
# ✅ Final Data Types:
# - x = "Ten" → str
# - y = True → bool
#
# Python allows dynamic typing, so variable types can change at runtime.

# %% [markdown]
# ## **04. Introduction to Strings**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# text = "Python\nProgramming"
# print(text)
# print("Length of string:", len(text))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Concept Testing – String Slicing
#
# Given the string name = "Maharashtra", write the output of the following:
#
# - name[2:7]
# - name[-3:]
# - name[:5]
# - name[::2]

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Identify the Error
#
# What is wrong with the following code snippet? Rewrite it correctly.
# ```python
# my_string = "Welcome"
# my_string[0] = 'w'
# print(my_string)
# ```

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Escape Sequence Handling
#
# Write a Python string that displays this exact output:
# ```python
# Hello	World
# He said, "Python is easy!"
# ```

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Applied Logic
#
# You are given a full name in a string format. Write code to extract:
# - First name
# - Last name
# - Initials
#
# Sample Input:
# ```python
# full_name = "Alan Turing"
# ```
# Expected Output:
# ```python
# First Name: Alan
# Last Name: Turing
# Initials: A.T.
# ```

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
#
# ```python
# Python
# Programming
# Length of string: 18
# ```
# The \n inserts a newline, but len() counts it as 1 character, so the total length = 6 (Python) + 1 (\n) + 11 (Programming) = 18.

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ✅ Output:
#
# - name[2:7] → "haras"
# - name[-3:] → "tra"
# - name[:5] → "Mahar"
# - name[::2] → "Mhrsra"
#
# Explanation:
# - [2:7] gives characters from index 2 to 6.
# - [-3:] gives the last 3 characters.
# - [:5] gives from beginning to index 4.
# - [::2] skips every second character.

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ❌ Error:
#
# ```python
# TypeError: 'str' object does not support item assignment
# ```
# ✅ Correct Code:
#
# ```python
# my_string = "w" + "elcome"
# print(my_string)
# ```
#
# Strings are immutable, so characters cannot be changed directly.

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Output:
#
# ```python
# Hello	World
# He said, "Python is easy!"
# ```
#
# Use \t for tab and wrap double quotes in single quotes (or escape them using \").

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# ✅ Code:
# ```python
# full_name = "Alan Turing"
#
# first_name = full_name.split()[0]
# last_name = full_name.split()[1]
# initials = first_name[0] + '.' + last_name[0] + '.'
#
# print("First Name:", first_name)
# print("Last Name:", last_name)
# print("Initials:", initials)
# ```
#
# ✅ Output:
# ```python
# First Name: Alan
# Last Name: Turing
# Initials: A.T.
# ```
#
# You can also do this more compactly using unpacking:
# ```python
# first, last = full_name.split()
# ```

# %% [markdown]
# ## **05. Indexing and Slicing**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# Given the string:
# ```python
# word = "PYTHONIC"
# ```
#
# What will be the output of the following expressions?
#
# - word[2]
# - word[-3]
# - word[1:5]
# - word[:4]
# - word[::2]
# - word[::-1]

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Error Identification
#
# What will be the output of the following code? If there's an error, state the reason clearly.
# ```python
# name = "India"
# print(name[10])
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Slicing to Reconstruct
#
# You are given a string:
# ```python
# sentence = "SlicingIsPowerful"
# ```
#
# Write a single slicing statement to extract and print the word "Power".

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Reverse Challenge
#
# Given a string:
# ```python
# palindrome = "madam"
# ```
#
# Write a one-line expression that checks whether the string is a palindrome (i.e., reads the same forward and backward). It should return True or False.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Construct from Pieces
#
# Given the string:
# ```python
# email = "student.university2025@gmail.com"
# ```
#
# Write code to extract:
# - The username (student.university2025)
# - The domain name (gmail)
# - The TLD (com)
#
# Use indexing and slicing only (no .split() allowed).

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# Output Prediction Answers
#
# - word[2] → 'T'
# - word[-3] → 'N'
# - word[1:5] → 'YTHO'
# - word[:4] → 'PYTH'
# - word[::2] → 'PTOC'
# - word[::-1] → 'CINOHTYP'

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ❌ Output:
#
# IndexError: string index out of range
# ```python
# The string "India" has only 5 characters (0 to 4). Index 10 doesn’t exist.
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Slicing to Reconstruct
# ```python
# sentence = "SlicingIsPowerful"
# ```
#
# To extract "Power":
# ✅ Code:
# ```python
# print(sentence[9:14])
# ```
#
# Index of 'P' is 9 and 'l' (end of 'Power') is at index 13.

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# Reverse Challenge
# ```python
# palindrome = "madam"
# ```
#
# ✅ One-liner expression:
# ```python
# palindrome == palindrome[::-1]
# ```
#
# ✅ Output:
# ```python
# True
# ```
#
# It compares the string to its reverse using slicing.

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Construct from Pieces
# ```python
# email = "student.university2025@gmail.com"
# ```
#
# ✅ Username:
# ```python
# email[:email.index('@')]  →  "student.university2025"
# ```
#
# ✅ Domain name:
# ```python
# email[email.index('@')+1 : email.index('.')]  →  "gmail"
# ```
#
# ✅ TLD:
# ```python
# email[email.index('.')+1:]  →  "com"
# ```
#
# All are achieved using indexing and slicing only, not .split().

# %% [markdown]
# ## **06. String Properties and Methods**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# s = "   Python Programming  "
# print(s.strip().lower().replace("python", "java"))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# True or False
#
# For the string text = "AI2025":
#
# - text.isalpha() → ___
# - text.isalnum() → ___
# - text.isdigit() → ___
# - text.startswith("AI") → ___
# - text.endswith("25") → ___

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Correction and Reasoning
#
# The following code is meant to capitalize every word in a sentence. However, it doesn’t behave as intended. Fix it and explain why it didn’t work originally.
# ```python
# sentence = "hello world"
# result = sentence.capitalize()
# print(result)  # Expected: Hello World
# ```

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# String Analytics
#
# You are given the string:
# ```python
# story = "Data is the new oil. Data drives decisions. Data is everywhere."
# ```
#
# Write code to:
# - Count how many times "Data" appears
# - Replace the word "Data" with "Information"
# - Check if the string ends with a period (".")

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Chaining Challenge
#
# Write a one-liner expression that transforms the string below to:
# "Welcome-to-Python-World"
#
# Input:
# ```python
# msg = "   welcome to PYTHON world   "
# ```
#
# Transformation required:
# - Strip extra whitespace
# - Convert to title case
# - Replace spaces with dashes

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# java programming
# ```
#
# .strip() removes leading/trailing spaces → "Python Programming"
#
# .lower() → "python programming"
#
# .replace("python", "java") → "java programming"

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# True or False
#
# For: text = "AI2025"
#
# - text.isalpha() → ❌ False (contains digits)
# - text.isalnum() → ✅ True (only letters and digits)
# - text.isdigit() → ❌ False (contains letters)
# - text.startswith("AI") → ✅ True
# - text.endswith("25") → ✅ True

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ❌ Original Code:
# ```python
# sentence = "hello world"
# result = sentence.capitalize()
# print(result)
# ```
# 🔍 Original Code Output:
# ```python
# Hello world
# ```
# .capitalize() only capitalizes the first letter of the entire string, not every word.
#
# ---
#
# ✅ Correct Code:
# ```python
# sentence = "hello world"
# result = sentence.title()
# print(result)
# ```
# ✅ Corrected Code Output:
# ```python
# Hello World
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# String Analytics
# ```python
# story = "Data is the new oil. Data drives decisions. Data is everywhere."
# ```
#
# ✅ Code:
# ```python
# print("Count:", story.count("Data"))  # Output: 3
# print("Replaced:", story.replace("Data", "Information"))
# print("Ends with '.':", story.endswith("."))
# ```
#
# ✅ Output:
# ```python
# Count: 3
# Replaced: Information is the new oil. Information drives decisions. Information is everywhere.
# Ends with '.': True
# ```

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Chaining Challenge
#
# Input:
# ```python
# msg = "   welcome to PYTHON world   "
# ```
#
# ✅ One-liner:
# ```python
# print(msg.strip().title().replace(" ", "-"))
# ```
#
# ✅ Output:
# ```python
# Welcome-To-Python-World
# ```

# %% [markdown]
# ## **07. Print Formatting with Strings**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# name = "Alice"
# age = 23
# print("My name is {} and I am {} years old.".format(name, age))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Fill in the Blanks
#
# Fill in the blanks to produce this output:
#
# ```python
# Product: Laptop | Price: ₹74999.00
# ```
# Code to be used:
# ```python
# product = "Laptop"
# price = 74999
# print("Product: {} | Price: ₹{:.2f}".format(_____, _____))
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Format Logic
#
# You are given the following code:
#
# ```python
# sentence = "Python is {} than {}"
# print(sentence.format("better"))
# ```
#
# This code raises an error or prints an unexpected result. Explain what’s wrong and how to fix it.

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Alignment and Width
#
# Write a line of code using .format() that prints the word "AI":
# - Right-aligned
# - In a field width of 10 characters
# - Surrounded by * on both sides
#
# Expected Output:
# ```python
# *        AI*
# ```

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# F-String Application
#
# You are given the following variables:
# ```python
# language = "Python"
# score = 98.6789
# ```
# Write an f-string that prints:
# ```python
# Language: Python | Score: 98.68%
# ```

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# My name is Alice and I am 23 years old.
# ```

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ✅ Output:
# ```python
# Product: Laptop | Price: ₹74999.00
# ```
# The .2f formats the float to 2 decimal places.

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Format Logic
# ```python
# sentence = "Python is {} than {}"
# print(sentence.format("better"))
# ```
#
# ❌ Issue:
# Only one value ("better") is passed to .format() but there are two placeholders ({}), so Python raises an IndexError.
#
# ✅ Fix:
# Pass both values:
# ```python
# print(sentence.format("better", "Java"))
# ```
# ✅ Output:
# ```python
# Python is better than Java
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# Alignment and Width
#
# ✅ Code:
# ```python
# print("*{:>10}*".format("AI"))
# ```
#
# ✅ Output:
# ```python
# *        AI*
# ```
# {:>10} means right-align in a field of width 10.

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# F-String Application
# ```python
# language = "Python"
# score = 98.6789
# print(f"Language: {language} | Score: {score:.2f}%")
# ```
#
# ✅ Output:
# ```python
# Language: Python | Score: 98.68%
# ```
# f-strings allow embedded expressions with formatting using {variable:.2f} syntax.

# %% [markdown]
# ## **08. Lists in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# nums = [10, 20, 30, 40, 50]
# nums[1:4] = [100, 200]
# print(nums)
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Code Correction
#
# What is wrong with this code? Fix it without changing the logic.
# ```python
# my_list = [1, 2, 3]
# my_list.append(4, 5)
# print(my_list)
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Application Logic
#
# You are given a list of student marks:
# ```python
# marks = [88, 76, 92, 85, 69]
# ```
#
# Write code to:
# - Remove the lowest mark
# - Insert 90 at the 2nd position
# - Reverse the list
#
# Then print the final list.

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Nested List Access
#
# Consider the following list:
# ```python
# data = [1, [2, 3, [4, 5]], 6]
# ```
#
# Write code to print only the number 5 using indexing.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# List Operations Challenge
#
# Given:
# ```python
# colors = ["red", "blue", "green"]
# ```
#
# Write a single line of code to:
# - Add "yellow" at the end
# - Insert "black" at index 1
# - Then sort the list in reverse alphabetical order

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
#
# ```python
# [10, 100, 200, 50]
# ```
# The slice nums[1:4] (which includes 20, 30, 40) is replaced with [100, 200].

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ❌ Error:
# .append() takes only one argument, but 4, 5 is two values.
#
# ✅ Fix:
# Option 1 (append a sublist):
# ```python
# my_list.append([4, 5])
# # Output: [1, 2, 3, [4, 5]]
# ```
#
# Option 2 (add both values individually):
# ```python
# my_list.append(4)
# my_list.append(5)
# # Output: [1, 2, 3, 4, 5]
# ```
# Or use .extend():
# ```python
# my_list.extend([4, 5])
# # Output: [1, 2, 3, 4, 5]
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ✅ Output:
# ```python
# [85, 92, 90, 76, 88]
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Output:
# ```python
# 5
# ```
#
# data[1] → [2, 3, [4, 5]]
#
# data[1][2] → [4, 5]
#
# data[1][2][1] → 5

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# ✅ Output:
# ```python
# ['yellow', 'red', 'green', 'blue', 'black']
# ```
#
# All operations are performed in a single chain of steps.

# %% [markdown]
# ## **09. Dictionaries in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# student = {"name": "Arya", "grade": "A", "age": 17}
# student["grade"] = "A+"
# student["city"] = "Pune"
# print(student)
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Safe Access
#
# You are given the dictionary:
# ```python
# data = {"id": 101, "name": "Kavya"}
# ```
# Write a one-line expression that:
# - Tries to get the value of key "email"
# - Returns "Not Provided" if the key doesn’t exist

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Dictionary Breakdown
#
# Given this dictionary:
# ```python
# person = {"name": "Ravi", "skills": ["Python", "SQL"], "details": {"age": 22, "city": "Mumbai"}}
# ```
#
# Answer the following:
# - How do you access "SQL"?
# - How do you get the person's city?
# - What is the output of len(person)?

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Use of Methods
#
# Given:
# ```python
# record = {"a": 10, "b": 20, "c": 30}
# ```
#
# Write code to:
# - Remove the key "b" using a method and store its value in a variable removed_val
# - Print all remaining keys
# - Print all remaining values

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Nested Dictionary Task
#
# Create a dictionary called students that stores the following data for two students:
# | Roll No | Name  | Marks |
# | ------- | ----- | ----- |
# | 101     | Aditi | 88    |
# | 102     | Manav | 92    |
#
# Then write code to:
# - Print the dictionary
# - Print Manav’s marks using dictionary access

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# {'name': 'Arya', 'grade': 'A+', 'age': 17, 'city': 'Pune'}
# ```
#
# The value of "grade" is updated, and a new key "city" is added.

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Safe Access
# ```python
# data = {"id": 101, "name": "Kavya"}
# ```
#
# ✅ One-liner:
# ```python
# data.get("email", "Not Provided")
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Dictionary Breakdown
# ```python
# person = {
#     "name": "Ravi",
#     "skills": ["Python", "SQL"],
#     "details": {"age": 22, "city": "Mumbai"}
# }
# ```
#
# a) Access "SQL":
# ```python
# person["skills"][1]
# ```
#
# b) Get city:
# ```python
# person["details"]["city"]
# ```
# c) Output of len(person) → 3
# - The dictionary has three top-level keys: "name", "skills", "details".

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Code:
#
# ```python
# removed_val = record.pop("b")           # removes key 'b'
# print(record.keys())                    # dict_keys(['a', 'c'])
# print(record.values())                  # dict_values([10, 30])
# ```

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# ✅ Dictionary Creation:
# ```python
# students = {
#     101: {"name": "Aditi", "marks": 88},
#     102: {"name": "Manav", "marks": 92}
# }
# ```
#
# ✅ Printing the dictionary:
# ```python
# print(students)
# ```
#
# ✅ Accessing Manav’s marks:
# ```python
# print(students[102]["marks"])  # Output: 92
# ```

# %% [markdown]
# ## **10. Tuples in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# t = (1, 2, 3, 2, 4, 2)
# print(t.count(2))
# print(t.index(4))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Identify the Error
#
# What is wrong with the following code? Rewrite it correctly.
# ```python
# data = (10, 20, 30)
# data[0] = 100
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Tuple Unpacking
#
# You are given the tuple:
# ```python
# info = ("Python", 3.11, "Stable")
# ```
#
# Write code to unpack this tuple into variables named lang, version, and status. Then print:
# ```python
# Language: Python
# Version: 3.11
# Status: Stable
# ```

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Nested Tuple Access
#
# Given:
# ```python
# person = ("Anya", 21, ("India", "Pune"))
# ```
#
# Write code to print only the city name using indexing.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Tuple Construction Logic
#
# Create a tuple called marks that contains 3 subjects’ marks: 87, 92, 76. Then:
# - Convert the tuple to a list
# - Add a new mark: 89
# - Convert it back to a tuple
# - Print the final tuple

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# 3
# 4
# ```
#
# .count(2) counts how many times 2 appears
#
# .index(4) returns the first index where 4 is found

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ❌ Error:
# ```python
# TypeError: 'tuple' object does not support item assignment
# ```
#
# ✅ Correct Code:
# You cannot modify a tuple. But to mimic change:
# ```python
# data = (100, 20, 30)  # Recreate the entire tuple
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ✅ Output:
# ```python
# Language: Python
# Version: 3.11
# Status: Stable
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Output:
# ```python
# Pune
# ```
#
# person[2] gives the nested tuple → ("India", "Pune")
#
# person[2][1] gets "Pune"

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# ✅ Output:
# ```python
# (87, 92, 76, 89)
# ```
#
# Tuples are immutable, so we use a list as an intermediate.

# %% [markdown]
# ## **11. Sets in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# nums = {1, 2, 2, 3, 4, 3}
# print(len(nums))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# You are given two sets:
# ```python
# a = {1, 2, 3, 4}
# b = {3, 4, 5, 6}
# ```
#
# Using both operators and methods, write code to find:
# - Elements common to both
# - Elements only in a but not in b
# - All elements from both sets without duplicates

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Safe Element Removal
#
# Given:
# ```python
# colors = {"red", "green", "blue"}
# ```
#
# Which method would you use to remove "yellow" without raising an error? Write the code.

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Application Logic
#
# Write code that performs the following:
# - Convert the string "programming" to a set of unique characters
# - Add the character 'z'
# - Remove the character 'g'
# - Print the final set

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Frozenset Challenge
#
# You are given:
# ```python
# frozen = frozenset([1, 2, 3])
# ```
#
# Attempt to add 4 to it using code. What happens? Why?

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# 4
# ```
#
# Sets only store unique elements, so {1, 2, 3, 4} → length is 4.

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# ✅ a) Common elements (intersection):
# ```python
# print(a & b)          # {3, 4}
# print(a.intersection(b))  # {3, 4}
# ```
#
# ✅ b) Elements in a but not in b (difference):
# ```python
# print(a - b)          # {1, 2}
# print(a.difference(b))    # {1, 2}
# ```
#
# ✅ c) All elements (union):
# ```python
# print(a | b)          # {1, 2, 3, 4, 5, 6}
# print(a.union(b))         # {1, 2, 3, 4, 5, 6}
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Safe Element Removal
# ```python
# colors = {"red", "green", "blue"}
# colors.discard("yellow")  # ✅ No error raised if element not found
# ```
#
# .remove("yellow") would raise a KeyError, but .discard() is safe.

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Output:
#
# A sample output might be:
# ```python
# {'z', 'm', 'r', 'p', 'i', 'n', 'a', 'o'}
# ```
#
# The actual order may vary since sets are unordered.

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Frozenset Challenge
#
# ❌ Output:
# ```python
# AttributeError: 'frozenset' object has no attribute 'add'
# ```
#
# Explanation: frozenset is immutable. You cannot modify it once created.

# %% [markdown]
# ## **12. Booleans in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# a = 10
# b = 5
# print(a > b and b == 5)
# print(not (a < 20 or b > 10))
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Truthy and Falsy
#
# Which of the following values will evaluate to False in a Boolean context? (Choose all that apply)
#
# - 0
# - []
# - "Python"
# - None
# - {}
# - "False"

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Logical Reasoning
#
# You are given:
# ```python
# x = 7
# y = 12
# ```
#
# Which of the following will evaluate to True? (You may select multiple)
#
# - x < y and x > 5
# - x > 10 or y == 12
# - not (x == 7)
# - x != y and y < 20

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Conditional Evaluation
#
# Write a code snippet using Boolean logic that prints "Access Granted" only if all of the following conditions are met:
# - username is not empty
# - password is not empty
# - attempts are less than 3
#
# Assume all variables are already defined.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Compare and Comment
#
# Explain the difference in output between the two expressions below:
# ```python
# print("False" == False)
# print(bool("False") == False)
# ```

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# True
# False
# ```
#
# a > b and b == 5 → 10 > 5 and 5 == 5 → True and True → True
#
# not (a < 20 or b > 10) → not (True or False) → not True → False

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Truthy and Falsy
#
# ❌ Falsy Values:
# - 0 → ✅ Falsy
# - [] → ✅ Falsy
# - "Python" → ❌ Truthy
# - None → ✅ Falsy
# - {} → ✅ Falsy
# - "False" → ❌ Truthy (non-empty string is always True)
#
# ✅ Correct answers: a, b, d, e

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Logical Reasoning
#
# Given:
# ```python
# x = 7
# y = 12
# ```
# ✅ Evaluations:
#
# - x < y and x > 5 → 7 < 12 and 7 > 5 → True ✅
# - x > 10 or y == 12 → False or True → True ✅
# - not (x == 7) → not True → False ❌
# - x != y and y < 20 → True and True → True ✅
#
# ✅ Correct answers: a, b, d

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# Conditional Evaluation
#
# ✅ Code:
# ```python
# if username and password and attempts < 3:
#     print("Access Granted")
# ```
#
# username and password being non-empty strings will evaluate to True if they are not empty.

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Compare and Comment
#
# print("False" == False)         # ❌ False
# print(bool("False") == False)   # ❌ False
#
# ✅ Output:
# ```python
# False
# False
# ```
#
# ✅ Explanation:
# - "False" is a non-empty string, so it is not equal to Boolean False.
# - bool("False") evaluates to True because any non-empty string is considered True.

# %% [markdown]
# ## **13. Input Output with Basic Files in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code if my_file.txt contains:
# ```txt
# Hello
# World
# ```
#
# Code:
# ```python
# f = open("my_file.txt")
# print(f.read())
# print(f.read())
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Error Identification
#
# What is the error in the following code? Fix it.
#
# ```python
# f = open("notes.txt", mode='w')
# content = f.read()
# print(content)
# f.close()
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Mode Understanding
#
# Match the following file modes with their correct behavior:
#
# a) 'r'
# b) 'w'
# c) 'a'
# d) 'r+'
#
# - Overwrites the file if it exists
# - Appends to the end of the file
# - Reads and writes from the beginning
# - Raises an error if file doesn’t exist

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# File Modification Task
#
# Write Python code that:
# - Opens a file called data.txt in append mode
# - Adds the following text to the file:
#
# ```txt
# Appended Line 1
# Appended Line 2
# ```
#
# Then reads and prints the full content of the file

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Conceptual
#
# Explain the benefit of using with open(...) as file: over the traditional method of opening and closing files manually.

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# Hello
# World
# ```
#
# - The first f.read() reads the entire content and moves the cursor to the end.
# - The second f.read() returns an empty string '' because there’s nothing left to read.

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Error Identification
#
# ❌ Error:
# ```python
# io.UnsupportedOperation: not readable
# ```
# - 'w' mode is write-only, you cannot read in this mode.
#
#
# ✅ Fix:
# - Use 'r' or 'r+' or open it in write mode and skip reading:
# ```python
# # Option 1 (Reading only)
# f = open("notes.txt", mode='r')  # if file exists
# content = f.read()
# f.close()
#
# # Option 2 (Writing only)
# f = open("notes.txt", mode='w')
# f.write("This is a new line.")
# f.close()
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Mode Understanding
#
# Match:
#
# | Mode      | Description                             |
# | --------- | --------------------------------------- |
# | a) `'r'`  | 4. Raises error if file doesn’t exist ✅ |
# | b) `'w'`  | 1. Overwrites the file ✅                |
# | c) `'a'`  | 2. Appends to the end ✅                 |
# | d) `'r+'` | 3. Reads and writes from beginning ✅    |

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# File Modification Task
#
# ✅ Output (if original file had content, it will stay):
# ```txt
# ...original file content...
# Appended Line 1
# Appended Line 2
# ```

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Conceptual
#
# ✅ Answer:
#
# Using with open(...) as file: is better because it:
# - Automatically closes the file after the block is executed, even if an error occurs
# - Prevents resource leakage (e.g., too many files left open)
# - Makes the code cleaner and safer
#
# Example:
# ```python
# with open("file.txt", "r") as f:
#     data = f.read()
# # File is now closed automatically
# ```

# %% [markdown]
# ## **14. Comparison Operators in Python**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
#
# ```python
# x = 12
# y = 18
# print(x == y)
# print(x != y)
# print(x <= y)
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Expression Evaluation
#
# Evaluate the following and write the output (True or False):
#
# - "Python" == "python"
# - 15 > 10 and 10 < 5
# - not (7 >= 3)
# - 5 + 5 == 10

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Conditional Statement
#
# Write a Python program that checks whether a number is within the range 50 to 100 (inclusive) and prints an appropriate message.

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Type Sensitivity
#
# What will be the output of the following?
# ```python
# print("100" == 100)
# print(100 == 100.0)
# ```
#
# Explain why the two expressions return different results.

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Multi-level Comparison
#
# Rewrite the following expression using a single comparison:
# ```python
# x > 5 and x < 10
# ```
#
# Also, evaluate it for x = 7.

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# False
# True
# True
# ```

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Expression Evaluation
#
# - "Python" == "python" → ❌ False
#
#   Case-sensitive comparison
#
# - 15 > 10 and 10 < 5 → ❌ False
#
#   True and False → False
#
# - not (7 >= 3) → ❌ False
#
#   7 >= 3 → True, so not True → False
#
# - 5 + 5 == 10 → ✅ True

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# ✅ Code:
# ```python
# num = int(input("Enter a number: "))
# if 50 <= num <= 100:
#     print("Number is within the range.")
# else:
#     print("Number is outside the range.")
# ```

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# Type Sensitivity
# ```python
# print("100" == 100)      # False
# print(100 == 100.0)      # True
# ```
#
# ✅ Explanation:
# - "100" == 100 → False because one is a string, the other is a number
# - 100 == 100.0 → True because Python considers int and float of same value as equal

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Multi-level Comparison
#
# Original:
# ```python
# x > 5 and x < 10
# ```
#
# ✅ Rewritten as:
# ```python
# 5 < x < 10
# ```
#
# If x = 7 → 5 < 7 < 10 → ✅ True

# %% [markdown]
# ## **15. Chaining Comparison Operators**

# %% [markdown]
# ### **Questions**

# %% [markdown]
# #### **Question No.1**

# %% [markdown]
# Output Prediction
#
# What will be the output of the following code?
# ```python
# x = 5
# print(1 < x < 10)
# print(1 > x < 10)
# ```

# %% [markdown]
# #### **Question No.2**

# %% [markdown]
# Logical Rewrite
#
# Rewrite the following code using chained comparison:
# ```python
# if score > 50 and score < 100:
#     print("Valid score")
# ```

# %% [markdown]
# #### **Question No.3**

# %% [markdown]
# Chained Logic Evaluation
#
# Evaluate the expression below and state whether it is True or False. Explain step-by-step:
# ```python
# 5 < 10 < 15 == 15
# ```

# %% [markdown]
# #### **Question No.4**

# %% [markdown]
# Error Identification
#
# Will the following code run correctly? If not, explain the mistake.
# ```python
# a = 5
# b = 10
# c = 15
# print(a < b > c)
# ```

# %% [markdown]
# #### **Question No.5**

# %% [markdown]
# Applied Scenario
#
# Write a program that checks if a temperature value is within a normal body temperature range (97.0°F to 99.0°F) and prints:
# - "Normal" if true
# - "Abnormal" otherwise
#
# Use chained comparison.

# %% [markdown]
# ### **Answers**

# %% [markdown]
# #### **Answer No.1**

# %% [markdown]
# ✅ Output:
# ```python
# True
# False
# ```
#
# - 1 < x < 10 → 1 < 5 and 5 < 10 → True
# - 1 > x < 10 → 1 > 5 and 5 < 10 → False and True → False

# %% [markdown]
# #### **Answer No.2**

# %% [markdown]
# Logical Rewrite
#
# Original:
# ```python
# if score > 50 and score < 100:
# ```
#
# ✅ Rewritten:
# ```python
# if 50 < score < 100:
#     print("Valid score")
# ```

# %% [markdown]
# #### **Answer No.3**

# %% [markdown]
# Chained Logic Evaluation
# ```python
# 5 < 10 < 15 == 15
# ```
#
# Step-by-step breakdown:
# - 5 < 10 → True
# - 10 < 15 → True
# - 15 == 15 → True
#
# ✅ Final result:
# ```python
# True
# ```
# - Python evaluates it as: 5 < 10 and 10 < 15 and 15 == 15

# %% [markdown]
# #### **Answer No.4**

# %% [markdown]
# ✅ Output:
# ```python
# False
# ```
#
# - No error – it's valid syntax.
# - It checks: a < b and b > c → 5 < 10 and 10 > 15 → True and False → False

# %% [markdown]
# #### **Answer No.5**

# %% [markdown]
# Applied Scenario
# ```python
# temp = float(input("Enter body temperature in Fahrenheit: "))
#
# if 97.0 <= temp <= 99.0:
#     print("Normal")
# else:
#     print("Abnormal")
# ```
#
# ✅ Example Outputs:
# - Input: 98.6 → Output: Normal
# - Input: 100.2 → Output: Abnormal

# %% [markdown]
# ## **🎉 Congratulations on completing Assessment Test 1! 🎉**
#
# You've just tested yourself on everything you've learned so far in the PyKing course.
# Whether you got them all correct or not, you're making serious progress.
#
# ✅ Keep practicing.
# 📈 Keep improving.
# 🚀 You're one step closer to mastering Python!
#
# 💬 If you have any questions or problems than regarding the test then let’s discuss → https://github.com/StudiYash/PyKing/discussions
