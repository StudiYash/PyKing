# %% [markdown]
# # **📘 Notebook 01: Print Statement and Python Comments**
#
# ## 🎯 Learning Objectives:
# - Understand how to use the `print()` function in Python
# - Learn the different types of comments in Python: single-line and multi-line
# - Develop the habit of writing clean, well-commented code
#
# 🕒 Estimated Time: 5 minutes

# %% [markdown]
# ## **Python Print Statement**

# %% [raw]
# ✅ The `print()` function in Python is used to display output to the screen.
# Below, we are printing the classic "Hello World" message, which is often used in your first program in any language.

# %%
print("Hello World") # 🟢 This line prints text to the console
# Out:
# Hello World

# %% [markdown]
# ## **Python Comments**

# %% [raw]
# 💡 Python ignores comments during execution. They're just for humans to understand the code.
# You can write:
# - Single-line comments using the `#` symbol
# - Multi-line comments using triple quotes: `'''` or `"""`

# %%
# This is a single line comment

""" This is a Multiline
Comment """

''' This is also a Multiline 
Comment '''

print("All 3 types of comments are shown")
# Out:
# All 3 types of comments are shown

# %% [markdown]
# ## **✅ Summary:**
#
# In this notebook, you learned:
# - How to print a statement in Python
# - The 1 type of Single-line Comment
# - The 2 types of Multiline Comments
#
# 💬 Got a doubt? Ask it here → https://github.com/StudiYash/PyKing/discussions
